# %% [markdown]
# # OPENCV Task

# %% [markdown]
# ### Try to solve on your own. Add comments and explain what you are trying to do or did.

# %% [markdown]
# # Question 1
# ### Open and plot/print the provided image.
# ### <img src = 'image.jpg'>

# %%
import matplotlib.pyplot as plt #importing matplotlib
from PIL import Image #importing matplotlib
image_path = './image.jpg'  #giving the path to the image
image= Image.open(image_path) #reading the path, imread can also be used 
#image= plt.imread(image_path) this can also be used to read image path
plt.imshow(image)  #showing/plotting the image
plt.show()

# %% [markdown]
# # Question 2
# ### Rotate the image 90 degrees and plot.

# %%
rotated_image = image.rotate(90) #rotating image 90 degree anticlosckwise, rotate is the mehtod of PIL
plt.imshow(rotated_image) #plot the rotated image
plt.show()

# %% [markdown]
# # Question 3
# ### Draw a rectangle around the image. The rectangle must be green in color.

# %%
from PIL import ImageDraw #importing imageDraw 
rectangle_image = ImageDraw.Draw(image) #creating a drawing object
image_width, image_height= image.size #getting the dimentions of the image
rectangle_image.rectangle([0,0,image_width-1, image_height-1], outline="green") #drawing the rectangle around the image using the object created using imagedraw
plt.imshow(image) #plotting the image
plt.axis('off') #removing axis
plt.show()

# %%
#using cv2 
import cv2 #imorting cv2
color=(0,255,0) #defining the color green
img = cv2.imread(image_path) # reading image path using cv2.imread
img_height, img_width= img.shape[:2] #defining the height and width
border_width = 2 #defining boarder width
cv2.rectangle(img,(0,0),(img_width-1, img_height-1), color, border_width) #draws a rectangle using rectangle method of cv2 around the image
imge= cv2.cvtColor(img, cv2.COLOR_BGR2RGB) #converting the BGR  to RGB as cv2 works in BGR 
plt.imshow(imge) #plotting the image
plt.axis('off')#removing the axis
plt.show()
